# %% [markdown]
# <a href="https://colab.research.google.com/github/PGLavergne/NYTCrosswordPredicter/blob/main/nytCrossword.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

dataSet = '/content/drive/MyDrive/nytcrosswords_modified.csv'
train_df = pd.read_csv(dataSet, nrows=5000)

# %% [markdown]
# This shows the first five entries of what this csv file looks like. The word and clue features were primarily my focus within this dataset, however, the date column became useful when I realized that the null values would interfere with the model.

# %%
train_df.head()
# Out:
#          Date     Word                                 Clue
# 0  10/31/2021      PAT  Action done while saying "Good dog"
# 1  10/31/2021  RASCALS                      Mischief-makers
# 2  10/31/2021      PEN          It might click for a writer
# 3  10/31/2021      SEP                             Fall mo.
# 4  10/31/2021      ECO                Kind to Mother Nature

# %%
import matplotlib.pyplot as plt

numeric_values = pd.to_numeric(train_df['Word'], errors='coerce')
null_entries = train_df.isnull().sum()
null_entries
# Out:
# Date     0
# Word    34
# Clue     0
# dtype: int64

# %%
null_word_entries = train_df[train_df['Word'].isnull()]
null_word_entries
# Out:
#               Date Word                   Clue
# 24006   12/24/2020  NaN                   Zero
# 43275    4/17/2020  NaN                  Empty
# 67323     6/7/2019  NaN            Of no value
# 93805    6/24/2018  NaN     No longer in force
# 141809   10/1/2016  NaN    { }, in mathematics
# 157990    3/3/2016  NaN  Having no legal force
# 176711    7/2/2015  NaN                Invalid
# 189051   1/22/2015  NaN                  Empty
# 195559  10/29/2014  NaN                   Void
# 229912    8/7/2013  NaN   Empty, as a math set
# 251214  10/31/2012  NaN          Lacking value
# 295562   3/30/2011  NaN         Empty, in math
# 344370    7/1/2009  NaN                   Zero
# 350968    4/6/2009  NaN           ___ and void
# 447651  10/23/2005  NaN                Invalid
# 480418   8/18/2004  NaN                   Zero
# 488526    5/5/2004  NaN        No longer legal
# 510877   7/19/2003  NaN   Lacking any elements
# 522564   2/17/2003  NaN          Without value
# 540417   6/30/2002  NaN            Nonexistent
# 541820   6/11/2002  NaN        Legally invalid
# 552743   1/20/2002  NaN                   Zero
# 565265    8/8/2001  NaN              Aleph-___
# 577557    3/1/2001  NaN              Valueless
# 593284    8/7/2000  NaN        Partner of void
# 593445    8/6/2000  NaN                   Zero
# 641843  11/17/1998  NaN         Empty, in math
# 645122   10/6/1998  NaN              Not valid
# 663360   2/11/1998  NaN            Nonexistent
# 668141  12/11/1997  NaN            Nonexistent
# 746622   2/18/1995  NaN                Invalid
# 747460    2/7/1995  NaN         Void's partner
# 749010   1/17/1995  NaN         Void's partner
# 763735   7/10/1994  NaN                   Zero

# %% [markdown]
# This code is preparing, building, and training a neural network for a text classification task using the New York Times Crossword dataset. It starts by loading the 'Clue' as features and 'Word' as the target variable from a DataFrame. Rows with missing values in these columns are dropped. The text data in the 'Clue' column is then tokenized using the Keras Tokenizer and padded to ensure uniform length. The target variable is one-hot encoded. The dataset is split into training and testing sets. The neural network model is constructed, consisting of an embedding layer, a flatten layer, and two dense layers. The model is compiled with the Adam optimizer and categorical crossentropy loss. It is then trained on the training set, and the training history is captured. Finally, the code generates a plot displaying the training and validation loss over the epochs to visualize the model's performance during training. The goal is to predict the correct 'Word' based on the textual context provided by the 'Clue' in the New York Times crossword dataset.
#
# As this is only really training a dataset to match a 'word' based on a 'clue', I assumed that because each input **must** match a desired output, the accuracy would remain low. And this model is also not accounting for token length, which must be constrained to a certain limit for each clue and the word it represents. Because if you've ever played a crossword, you'll know that the size of the word is just as important as the word it's adjacent to.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt

# Assuming 'Word' is the target variable and 'Clue' is the feature
X = train_df['Clue']
y = train_df['Word']

# Drop rows with missing values
nyt = train_df.dropna(subset=['Clue', 'Word'])

# Convert text data to numerical features using Tokenizer
max_words = 1000
tokenizer = Tokenizer(num_words=max_words, oov_token='<OOV>')
tokenizer.fit_on_texts(X)
X_sequence = tokenizer.texts_to_sequences(X)
X_padded = pad_sequences(X_sequence)

# Convert target variable to categorical
y_categorical = pd.get_dummies(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_padded, y_categorical, test_size=0.2, random_state=42)

# Build the neural network model
model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=50, input_length=X_padded.shape[1]))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(y_categorical.shape[1], activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model and capture the training history
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 100/100 [==============================] - 3s 21ms/step - loss: 8.3350 - accuracy: 9.3750e-04 - val_loss: 8.3510 - val_accuracy: 0.0012
# Epoch 2/50
# 100/100 [==============================] - 3s 25ms/step - loss: 8.2802 - accuracy: 6.2500e-04 - val_loss: 8.5235 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 100/100 [==============================] - 3s 25ms/step - loss: 8.1466 - accuracy: 0.0019 - val_loss: 8.9480 - val_accuracy: 0.0012
# Epoch 4/50
# 100/100 [==============================] - 2s 22ms/step - loss: 7.8785 - accuracy: 0.0041 - val_loss: 9.4925 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 100/100 [==============================] - 2s 16ms/step - loss: 7.0409 - accuracy: 0.0125 - val_loss: 11.0954 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 100/100 [==============================] - 2s 16ms/step - loss: 5.8647 - accuracy: 0.0631 - val_loss: 13.2787 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 100/100 [==============================] - 2s 16ms/step - loss: 4.9118 - accuracy: 0.1356 - val_loss: 14.9359 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 100/100 [==============================] - 2s 16ms/step - loss: 4.2627 - accuracy: 0.2075 - val_loss: 16.4682 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 100/100 [==============================] - 2s 16ms/step - loss: 3.7897 - accuracy: 0.2794 - val_loss: 17.2471 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 100/100 [==============================] - 2s 18ms/step - loss: 3.4102 - accuracy: 0.3441 - val_loss: 18.3594 - val_accuracy: 0.0012
# Epoch 11/50
# 100/100 [==============================] - 3s 25ms/step - loss: 3.0920 - accuracy: 0.3862 - val_loss: 19.1427 - val_accuracy: 0.0012
# Epoch 12/50
# 100/100 [==============================] - 2s 24ms/step - loss: 2.8214 - accuracy: 0.4428 - val_loss: 19.7750 - val_accuracy: 0.0037
# Epoch 13/50
# 100/100 [==============================] - 2s 25ms/step - loss: 2.5929 - accuracy: 0.4894 - val_loss: 20.0895 - val_accuracy: 0.0012
# Epoch 14/50
# 100/100 [==============================] - 2s 16ms/step - loss: 2.3911 - accuracy: 0.5294 - val_loss: 20.6464 - val_accuracy: 0.0025
# Epoch 15/50
# 100/100 [==============================] - 2s 16ms/step - loss: 2.2203 - accuracy: 0.5647 - val_loss: 20.8287 - val_accuracy: 0.0025
# Epoch 16/50
# 100/100 [==============================] - 2s 16ms/step - loss: 2.0777 - accuracy: 0.5906 - val_loss: 21.6573 - val_accuracy: 0.0037
# Epoch 17/50
# 100/100 [==============================] - 2s 16ms/step - loss: 1.9492 - accuracy: 0.6125 - val_loss: 21.1112 - val_accuracy: 0.0050
# Epoch 18/50
# 100/100 [==============================] - 2s 16ms/step - loss: 1.8417 - accuracy: 0.6322 - val_loss: 21.8678 - val_accuracy: 0.0050
# Epoch 19/50
# 100/100 [==============================] - 2s 16ms/step - loss: 1.7593 - accuracy: 0.6469 - val_loss: 21.9819 - val_accuracy: 0.0037
# Epoch 20/50
# 100/100 [==============================] - 2s 22ms/step - loss: 1.6745 - accuracy: 0.6725 - val_loss: 21.9784 - val_accuracy: 0.0050
# Epoch 21/50
# 100/100 [==============================] - 2s 25ms/step - loss: 1.6185 - accuracy: 0.6741 - val_loss: 21.7107 - val_accuracy: 0.0050
# Epoch 22/50
# 100/100 [==============================] - 2s 24ms/step - loss: 1.5589 - accuracy: 0.6900 - val_loss: 21.9696 - val_accuracy: 0.0063
# Epoch 23/50
# 100/100 [==============================] - 2s 20ms/step - loss: 1.5177 - accuracy: 0.6950 - val_loss: 22.1130 - val_accuracy: 0.0037
# Epoch 24/50
# 100/100 [==============================] - 2s 16ms/step - loss: 1.4754 - accuracy: 0.7044 - val_loss: 22.3326 - val_accuracy: 0.0037
# Epoch 25/50
# 100/100 [==============================] - 2s 16ms/step - loss: 1.4361 - accuracy: 0.7094 - val_loss: 22.0400 - val_accuracy: 0.0050
# Epoch 26/50
# 100/100 [==============================] - 2s 16ms/step - loss: 1.4072 - accuracy: 0.7131 - val_loss: 22.6514 - val_accuracy: 0.0063
# Epoch 27/50
# 100/100 [==============================] - 2s 16ms/step - loss: 1.3820 - accuracy: 0.7150 - val_loss: 22.3047 - val_accuracy: 0.0037
# Epoch 28/50
# 100/100 [==============================] - 2s 16ms/step - loss: 1.3636 - accuracy: 0.7131 - val_loss: 22.1843 - val_accuracy: 0.0050
# Epoch 29/50
# 100/100 [==============================] - 2s 20ms/step - loss: 1.3451 - accuracy: 0.7103 - val_loss: 22.2784 - val_accuracy: 0.0037
# Epoch 30/50
# 100/100 [==============================] - 2s 24ms/step - loss: 1.3302 - accuracy: 0.7153 - val_loss: 22.2955 - val_accuracy: 0.0037
# Epoch 31/50
# 100/100 [==============================] - 2s 25ms/step - loss: 1.3157 - accuracy: 0.7113 - val_loss: 22.2859 - val_accuracy: 0.0050
# Epoch 32/50
# 100/100 [==============================] - 2s 22ms/step - loss: 1.2996 - accuracy: 0.7125 - val_loss: 22.5669 - val_accuracy: 0.0037
# Epoch 33/50
# 100/100 [==============================] - 2s 16ms/step - loss: 1.2923 - accuracy: 0.7131 - val_loss: 22.2144 - val_accuracy: 0.0050
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt

# Assuming 'Word' is the target variable and 'Clue' is the feature
X = train_df['Clue']
y = train_df['Word']

# Drop rows with missing values
nyt = train_df.dropna(subset=['Clue', 'Word'])

# Convert text data to numerical features using Tokenizer
max_words = 1000
tokenizer = Tokenizer(num_words=max_words, oov_token='<OOV>')
tokenizer.fit_on_texts(X)
X_sequence = tokenizer.texts_to_sequences(X)
X_padded = pad_sequences(X_sequence)

# Convert target variable to categorical
y_categorical = pd.get_dummies(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_padded, y_categorical, test_size=0.3, random_state=42)

# Build the neural network model
model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=50, input_length=X_padded.shape[1]))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(y_categorical.shape[1], activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model and capture the training history
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 88/88 [==============================] - 4s 26ms/step - loss: 8.3336 - accuracy: 0.0000e+00 - val_loss: 8.3450 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 88/88 [==============================] - 1s 16ms/step - loss: 8.2798 - accuracy: 7.1429e-04 - val_loss: 8.6676 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 88/88 [==============================] - 1s 16ms/step - loss: 8.1377 - accuracy: 0.0014 - val_loss: 8.9618 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 88/88 [==============================] - 2s 24ms/step - loss: 7.8916 - accuracy: 0.0018 - val_loss: 9.6940 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 88/88 [==============================] - 2s 25ms/step - loss: 7.2033 - accuracy: 0.0086 - val_loss: 10.8237 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 88/88 [==============================] - 2s 25ms/step - loss: 6.1769 - accuracy: 0.0264 - val_loss: 12.5267 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 88/88 [==============================] - 2s 21ms/step - loss: 5.3852 - accuracy: 0.0700 - val_loss: 14.1701 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 88/88 [==============================] - 1s 15ms/step - loss: 4.8244 - accuracy: 0.1196 - val_loss: 15.1306 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 88/88 [==============================] - 1s 16ms/step - loss: 4.3436 - accuracy: 0.1800 - val_loss: 16.4716 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 88/88 [==============================] - 1s 16ms/step - loss: 3.9298 - accuracy: 0.2421 - val_loss: 17.2164 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 88/88 [==============================] - 1s 16ms/step - loss: 3.5743 - accuracy: 0.2946 - val_loss: 17.8428 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 88/88 [==============================] - 1s 16ms/step - loss: 3.2531 - accuracy: 0.3564 - val_loss: 18.5220 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 88/88 [==============================] - 1s 16ms/step - loss: 2.9847 - accuracy: 0.4029 - val_loss: 19.0123 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 88/88 [==============================] - 2s 19ms/step - loss: 2.7364 - accuracy: 0.4489 - val_loss: 19.5970 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 88/88 [==============================] - 2s 25ms/step - loss: 2.5232 - accuracy: 0.4911 - val_loss: 19.8087 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 88/88 [==============================] - 2s 25ms/step - loss: 2.3344 - accuracy: 0.5364 - val_loss: 20.1384 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 88/88 [==============================] - 2s 24ms/step - loss: 2.1830 - accuracy: 0.5571 - val_loss: 20.3879 - val_accuracy: 0.0014
# Epoch 18/50
# 88/88 [==============================] - 2s 18ms/step - loss: 2.0359 - accuracy: 0.5882 - val_loss: 20.7116 - val_accuracy: 0.0029
# Epoch 19/50
# 88/88 [==============================] - 1s 17ms/step - loss: 1.9212 - accuracy: 0.6068 - val_loss: 20.8271 - val_accuracy: 0.0029
# Epoch 20/50
# 88/88 [==============================] - 1s 16ms/step - loss: 1.8249 - accuracy: 0.6282 - val_loss: 20.9999 - val_accuracy: 0.0029
# Epoch 21/50
# 88/88 [==============================] - 1s 16ms/step - loss: 1.7355 - accuracy: 0.6475 - val_loss: 21.1315 - val_accuracy: 0.0029
# 88/88 [==============================] - 1s 16ms/step - loss: 1.2002 - accuracy: 0.7257 - val_loss: 20.7640 - val_accuracy: 0.0043
# Epoch 41/50
# 88/88 [==============================] - 1s 16ms/step - loss: 1.1960 - accuracy: 0.7250 - val_loss: 20.8686 - val_accuracy: 0.0043
# Epoch 42/50
# 88/88 [==============================] - 1s 16ms/step - loss: 1.1937 - accuracy: 0.7232 - val_loss: 20.9191 - val_accuracy: 0.0043
# Epoch 43/50
# 88/88 [==============================] - 1s 16ms/step - loss: 1.1870 - accuracy: 0.7250 - val_loss: 20.8782 - val_accuracy: 0.0043
# Epoch 44/50
# 88/88 [==============================] - 1s 16ms/step - loss: 1.1804 - accuracy: 0.7254 - val_loss: 20.7324 - val_accuracy: 0.0043
# Epoch 45/50
# 88/88 [==============================] - 1s 16ms/step - loss: 1.1715 - accuracy: 0.7257 - val_loss: 20.8584 - val_accuracy: 0.0043
# Epoch 46/50
# 88/88 [==============================] - 2s 18ms/step - loss: 1.1720 - accuracy: 0.7254 - val_loss: 20.7659 - val_accuracy: 0.0043
# Epoch 47/50
# 88/88 [==============================] - 2s 24ms/step - loss: 1.1686 - accuracy: 0.7243 - val_loss: 20.8661 - val_accuracy: 0.0043
# Epoch 48/50
# 88/88 [==============================] - 2s 26ms/step - loss: 1.1613 - accuracy: 0.7257 - val_loss: 20.6675 - val_accuracy: 0.0043
# Epoch 49/50
# 88/88 [==============================] - 3s 31ms/step - loss: 1.1583 - accuracy: 0.7257 - val_loss: 20.6976 - val_accuracy: 0.0043
# Epoch 50/50
# 88/88 [==============================] - 5s 54ms/step - loss: 1.1572 - accuracy: 0.7239 - val_loss: 20.6989 - val_accuracy: 0.0043

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt

# Assuming 'Word' is the target variable and 'Clue' is the feature
X = train_df['Clue']
y = train_df['Word']

# Drop rows with missing values
nyt = train_df.dropna(subset=['Clue', 'Word'])

# Convert text data to numerical features using Tokenizer
max_words = 1000
tokenizer = Tokenizer(num_words=max_words, oov_token='<OOV>')
tokenizer.fit_on_texts(X)
X_sequence = tokenizer.texts_to_sequences(X)
X_padded = pad_sequences(X_sequence)

# Convert target variable to categorical
y_categorical = pd.get_dummies(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_padded, y_categorical, test_size=0.4, random_state=42)

# Build the neural network model
model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=50, input_length=X_padded.shape[1]))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(y_categorical.shape[1], activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model and capture the training history
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 75/75 [==============================] - 2s 19ms/step - loss: 8.3325 - accuracy: 0.0000e+00 - val_loss: 8.3399 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 75/75 [==============================] - 1s 16ms/step - loss: 8.2699 - accuracy: 8.3333e-04 - val_loss: 8.5534 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 75/75 [==============================] - 1s 17ms/step - loss: 8.0019 - accuracy: 4.1667e-04 - val_loss: 9.0854 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 75/75 [==============================] - 1s 17ms/step - loss: 7.8139 - accuracy: 8.3333e-04 - val_loss: 9.6197 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 75/75 [==============================] - 1s 16ms/step - loss: 7.4785 - accuracy: 0.0042 - val_loss: 10.4609 - val_accuracy: 0.0000e+00
# Epoch 6/50
#
- val_accuracy: 0.0000e+00
# Epoch 31/50
# 75/75 [==============================] - 2s 25ms/step - loss: 1.5665 - accuracy: 0.6687 - val_loss: 23.1621 - val_accuracy: 0.0017
# Epoch 32/50
# 75/75 [==============================] - 2s 27ms/step - loss: 1.5337 - accuracy: 0.6829 - val_loss: 23.2012 - val_accuracy: 0.0017
# Epoch 33/50
# 75/75 [==============================] - 2s 24ms/step - loss: 1.4899 - accuracy: 0.6883 - val_loss: 23.8174 - val_accuracy: 0.0017
# Epoch 34/50
# 75/75 [==============================] - 1s 16ms/step - loss: 1.4560 - accuracy: 0.6971 - val_loss: 23.2664 - val_accuracy: 0.0017
# Epoch 35/50
# 75/75 [==============================] - 1s 17ms/step - loss: 1.4295 - accuracy: 0.7013 - val_loss: 23.6842 - val_accuracy: 0.0017
# Epoch 36/50
# 75/75 [==============================] - 1s 17ms/step - loss: 1.3957 - accuracy: 0.6996 - val_loss: 23.6180 - val_accuracy: 0.0017
# Epoch 37/50
# 75/75 [==============================] - 1s 16ms/step - loss: 1.3688 - accuracy: 0.7108 - val_loss: 23.8692 - val_accuracy: 0.0017
# Epoch 38/50
# 75/75 [==============================] - 1s 17ms/step - loss: 1.3499 - accuracy: 0.7179 - val_loss: 24.0025 - val_accuracy: 0.0017
# Epoch 39/50
# 75/75 [==============================] - 1s 17ms/step - loss: 1.3306 - accuracy: 0.7188 - val_loss: 24.0781 - val_accuracy: 0.0017
# Epoch 40/50
# 75/75 [==============================] - 1s 17ms/step - loss: 1.3118 - accuracy: 0.7171 - val_loss: 24.0194 - val_accuracy: 0.0017
# Epoch 41/50
# 75/75 [==============================] - 2s 21ms/step - loss: 1.2961 - accuracy: 0.7225 - val_loss: 24.3491 - val_accuracy: 0.0017
# Epoch 42/50
# 75/75 [==============================] - 2s 25ms/step - loss: 1.2734 - accuracy: 0.7250 - val_loss: 24.2713 - val_accuracy: 0.0017
# Epoch 43/50
# 75/75 [==============================] - 2s 27ms/step - loss: 1.2687 - accuracy: 0.7221 - val_loss: 24.3390 - val_accuracy: 0.0017
# Epoch 44/50
# 75/75 [==============================] - 2s 27ms/step - loss: 1.2489 - accuracy: 0.7250 - val_loss: 24.1616 - val_accuracy: 0.0017
# Epoch 45/50
# 75/75 [==============================] - 2s 20ms/step - loss: 1.2430 - accuracy: 0.7283 - val_loss: 24.5746 - val_accuracy: 0.0017
# Epoch 46/50
# 75/75 [==============================] - 1s 16ms/step - loss: 1.2288 - accuracy: 0.7246 - val_loss: 24.1241 - val_accuracy: 0.0017
# Epoch 47/50
# 75/75 [==============================] - 1s 16ms/step - loss: 1.2202 - accuracy: 0.7233 - val_loss: 24.3205 - val_accuracy: 0.0017
# Epoch 48/50
# 75/75 [==============================] - 1s 18ms/step - loss: 1.2122 - accuracy: 0.7262 - val_loss: 24.5299 - val_accuracy: 0.0017
# Epoch 49/50
# 75/75 [==============================] - 1s 17ms/step - loss: 1.2037 - accuracy: 0.7229 - val_loss: 24.4656 - val_accuracy: 0.0017
# Epoch 50/50
# 75/75 [==============================] - 1s 17ms/step - loss: 1.1932 - accuracy: 0.7275 - val_loss: 24.6037 - val_accuracy: 0.0017
