# %% [markdown]
# <a href="https://colab.research.google.com/github/PGLavergne/NYTCrosswordPredicter/blob/main/nytCrossword.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

dataSet = '/content/drive/MyDrive/nytcrosswords_modified.csv'
dataSet_full = pd.read_csv(dataSet)
train_df = pd.read_csv(dataSet, nrows=10000)

# %% [markdown]
# As you can see, this is a rather large dataset that I've had to constrict to only the first 10000 rows for certain types of analysis.

# %%
dataSet_full
# Out:
#               Date     Word                                 Clue
# 0       10/31/2021      PAT  Action done while saying "Good dog"
# 1       10/31/2021  RASCALS                      Mischief-makers
# 2       10/31/2021      PEN          It might click for a writer
# 3       10/31/2021      SEP                             Fall mo.
# 4       10/31/2021      ECO                Kind to Mother Nature
# ...            ...      ...                                  ...
# 781568  11/21/1993      NAT                      Actor Pendleton
# 781569  11/21/1993    SHRED                                  Bit
# 781570  11/21/1993      NEA                       Teachers' org.
# 781571  11/21/1993      BEG                             Petition
# 781572  11/21/1993      SIS                          Family girl
#
# [781573 rows x 3 columns]

# %% [markdown]
# This shows the first five entries of what this csv file looks like. The word and clue features were primarily my focus within this dataset, however, the date column became useful when I realized that the null values would interfere with the model.

# %%
dataSet.head()
# Out:
#          Date     Word                                 Clue
# 0  10/31/2021      PAT  Action done while saying "Good dog"
# 1  10/31/2021  RASCALS                      Mischief-makers
# 2  10/31/2021      PEN          It might click for a writer
# 3  10/31/2021      SEP                             Fall mo.
# 4  10/31/2021      ECO                Kind to Mother Nature

# %%
import matplotlib.pyplot as plt

numeric_values = pd.to_numeric(dataSet['Word'], errors='coerce')
null_entries = dataSet.isnull().sum()
null_entries
# Out:
# Date     0
# Word    34
# Clue     0
# dtype: int64

# %%
null_word_entries = train_df[dataSet['Word'].isnull()]
null_word_entries
# Out:
#               Date Word                   Clue
# 24006   12/24/2020  NaN                   Zero
# 43275    4/17/2020  NaN                  Empty
# 67323     6/7/2019  NaN            Of no value
# 93805    6/24/2018  NaN     No longer in force
# 141809   10/1/2016  NaN    { }, in mathematics
# 157990    3/3/2016  NaN  Having no legal force
# 176711    7/2/2015  NaN                Invalid
# 189051   1/22/2015  NaN                  Empty
# 195559  10/29/2014  NaN                   Void
# 229912    8/7/2013  NaN   Empty, as a math set
# 251214  10/31/2012  NaN          Lacking value
# 295562   3/30/2011  NaN         Empty, in math
# 344370    7/1/2009  NaN                   Zero
# 350968    4/6/2009  NaN           ___ and void
# 447651  10/23/2005  NaN                Invalid
# 480418   8/18/2004  NaN                   Zero
# 488526    5/5/2004  NaN        No longer legal
# 510877   7/19/2003  NaN   Lacking any elements
# 522564   2/17/2003  NaN          Without value
# 540417   6/30/2002  NaN            Nonexistent
# 541820   6/11/2002  NaN        Legally invalid
# 552743   1/20/2002  NaN                   Zero
# 565265    8/8/2001  NaN              Aleph-___
# 577557    3/1/2001  NaN              Valueless
# 593284    8/7/2000  NaN        Partner of void
# 593445    8/6/2000  NaN                   Zero
# 641843  11/17/1998  NaN         Empty, in math
# 645122   10/6/1998  NaN              Not valid
# 663360   2/11/1998  NaN            Nonexistent
# 668141  12/11/1997  NaN            Nonexistent
# 746622   2/18/1995  NaN                Invalid
# 747460    2/7/1995  NaN         Void's partner
# 749010   1/17/1995  NaN         Void's partner
# 763735   7/10/1994  NaN                   Zero

# %% [markdown]
# This code is preparing, building, and training a neural network for a text classification task using the New York Times Crossword dataset. It starts by loading the 'Clue' as features and 'Word' as the target variable from a DataFrame. Rows with missing values in these columns are dropped. The text data in the 'Clue' column is then tokenized using the Keras Tokenizer and padded to ensure uniform length. The target variable is one-hot encoded. The dataset is split into training and testing sets. The neural network model is constructed, consisting of an embedding layer, a flatten layer, and two dense layers. The model is compiled with the Adam optimizer and categorical crossentropy loss. It is then trained on the training set, and the training history is captured. Finally, the code generates a plot displaying the training and validation loss over the epochs to visualize the model's performance during training. The goal is to predict the correct 'Word' based on the textual context provided by the 'Clue' in the New York Times crossword dataset.
#
# As this is only really training a dataset to match a 'word' based on a 'clue', I assumed that because each input **must** match a desired output, the accuracy would remain low. And this model is also not accounting for token length, which must be constrained to a certain limit for each clue and the word it represents. Because if you've ever played a crossword, you'll know that the size of the word is just as important as the word it's adjacent to.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt

# Assuming 'Word' is the target variable and 'Clue' is the feature
X = train_df['Clue']
y = train_df['Word']

# Drop rows with missing values
nyt = train_df.dropna(subset=['Clue', 'Word'])

# Convert text data to numerical features using Tokenizer
max_words = 1000
tokenizer = Tokenizer(num_words=max_words, oov_token='<OOV>')
tokenizer.fit_on_texts(X)
X_sequence = tokenizer.texts_to_sequences(X)
X_padded = pad_sequences(X_sequence)

# Convert target variable to categorical
y_categorical = pd.get_dummies(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_padded, y_categorical, test_size=0.2, random_state=42)

# Build the neural network model
model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=50, input_length=X_padded.shape[1]))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(y_categorical.shape[1], activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model and capture the training history
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 200/200 [==============================] - 6s 26ms/step - loss: 8.8994 - accuracy: 3.1250e-04 - val_loss: 8.9270 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 200/200 [==============================] - 8s 39ms/step - loss: 8.8108 - accuracy: 1.5625e-04 - val_loss: 9.0671 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 200/200 [==============================] - 7s 35ms/step - loss: 8.4900 - accuracy: 0.0020 - val_loss: 9.6417 - val_accuracy: 6.2500e-04
# Epoch 4/50
# 200/200 [==============================] - 5s 26ms/step - loss: 7.5172 - accuracy: 0.0091 - val_loss: 11.0204 - val_accuracy: 0.0012
# Epoch 5/50
# 200/200 [==============================] - 6s 29ms/step - loss: 6.3204 - accuracy: 0.0530 - val_loss: 12.8141 - val_accuracy: 6.2500e-04
# Epoch 6/50
# 200/200 [==============================] - 8s 40ms/step - loss: 5.3121 - accuracy: 0.1223 - val_loss: 14.5494 - val_accuracy: 0.0025
# Epoch 7/50
# 200/200 [==============================] - 6s 28ms/step - loss: 4.5583 - accuracy: 0.2014 - val_loss: 15.8389 - val_accuracy: 0.0031
# Epoch 8/50
# 200/200 [==============================] - 5s 25ms/step - loss: 4.0007 - accuracy: 0.2759 - val_loss: 17.3310 - val_accuracy: 0.0050
# Epoch 9/50
# 200/200 [==============================] - 7s 37ms/step - loss: 3.5484 - accuracy: 0.3438 - val_loss: 18.5143 - val_accuracy: 0.0044
# Epoch 10/50
# 200/200 [==============================] - 6s 28ms/step - loss: 3.1902 - accuracy: 0.4127 - val_loss: 19.3882 - val_accuracy: 0.0075
# Epoch 11/50
# 200/200 [==============================] - 5s 24ms/step - loss: 2.8911 - accuracy: 0.4600 - val_loss: 20.3880 - val_accuracy: 0.0075
# Epoch 12/50
# 200/200 [==============================] - 8s 41ms/step - loss: 2.6480 - accuracy: 0.4988 - val_loss: 20.7661 - val_accuracy: 0.0075
# Epoch 13/50
# 200/200 [==============================] - 6s 32ms/step - loss: 2.4541 - accuracy: 0.5317 - val_loss: 21.5160 - val_accuracy: 0.0094
# Epoch 14/50
# 200/200 [==============================] - 5s 24ms/step - loss: 2.2955 - accuracy: 0.5666 - val_loss: 21.8581 - val_accuracy: 0.0088
# Epoch 15/50
# 200/200 [==============================] - 6s 29ms/step - loss: 2.1697 - accuracy: 0.5864 - val_loss: 21.9154 - val_accuracy: 0.0094
# Epoch 16/50
# 200/200 [==============================] - 7s 37ms/step - loss: 2.0655 - accuracy: 0.6080 - val_loss: 22.1666 - val_accuracy: 0.0081
# Epoch 17/50
# 200/200 [==============================] - 6s 30ms/step - loss: 1.9771 - accuracy: 0.6227 - val_loss: 22.6556 - val_accuracy: 0.0088
# Epoch 18/50
# 200/200 [==============================] - 5s 26ms/step - loss: 1.9077 - accuracy: 0.6373 - val_loss: 22.8046 - val_accuracy: 0.0094
# Epoch 19/50
# 200/200 [==============================] - 7s 36ms/step - loss: 1.8513 - accuracy: 0.6461 - val_loss: 22.6146 - val_accuracy: 0.0106
# Epoch 20/50
# 200/200 [==============================] - 6s 30ms/step - loss: 1.8050 - accuracy: 0.6486 - val_loss: 22.5350 - val_accuracy: 0.0113
# Epoch 21/50
# 200/200 [==============================] - 5s 26ms/step - loss: 1.7692 - accuracy: 0.6531 - val_loss: 22.8791 - val_accuracy: 0.0094
# Epoch 22/50
# 200/200 [==============================] - 8s 40ms/step - loss: 1.7380 - accuracy: 0.6545 - val_loss: 23.0750 - val_accuracy: 0.0131
# Epoch 23/50
# 200/200 [==============================] - 7s 33ms/step - loss: 1.7107 - accuracy: 0.6559 - val_loss: 23.1717 - val_accuracy: 0.0125
# Epoch 24/50
# 200/200 [==============================] - 5s 24ms/step - loss: 1.6859 - accuracy: 0.6594 - val_loss: 22.7086 - val_accuracy: 0.0094
# Epoch 25/50
# 200/200 [==============================] - 6s 30ms/step - loss: 1.6702 - accuracy: 0.6583 - val_loss: 22.7797 - val_accuracy: 0.0100
# Epoch 26/50
# 200/200 [==============================] - 7s 36ms/step - loss: 1.6569 - accuracy: 0.6550 - val_loss: 22.6623 - val_accuracy: 0.0100
# Epoch 27/50
# 200/200 [==============================] - 6s 28ms/step - loss: 1.6382 - accuracy: 0.6609 - val_loss: 22.6537 - val_accuracy: 0.0106
# Epoch 28/50
# 200/200 [==============================] - 5s 27ms/step - loss: 1.6300 - accuracy: 0.6600 - val_loss: 22.8585 - val_accuracy: 0.0094
# Epoch 29/50
# 200/200 [==============================] - 7s 36ms/step - loss: 1.6167 - accuracy: 0.6586 - val_loss: 22.3162 - val_accuracy: 0.0119
# Epoch 30/50
# 200/200 [==============================] - 6s 28ms/step - loss: 1.6052 - accuracy: 0.6639 - val_loss: 23.0423 - val_accuracy: 0.0106
# Epoch 31/50
# 200/200 [==============================] - 5s 27ms/step - loss: 1.5966 - accuracy: 0.6612 - val_loss: 22.6624 - val_accuracy: 0.0106
# Epoch 32/50
# 200/200 [==============================] - 8s 41ms/step - loss: 1.5901 - accuracy: 0.6606 - val_loss: 22.3759 - val_accuracy: 0.0100
# Epoch 33/50
# 200/200 [==============================] - 7s 33ms/step - loss: 1.5828 - accuracy: 0.6592 - val_loss: 22.7081 - val_accuracy: 0.0100
# Epoch 34/50
# 200/200 [==============================] - 5s 25ms/step - loss: 1.5771 - accuracy: 0.6603 - val_loss: 23.0608 - val_accuracy: 0.0100
# Epoch 35/50
# 200/200 [==============================] - 6s 29ms/step - loss: 1.5719 - accuracy: 0.6595 - val_loss: 22.8637 - val_accuracy: 0.0100
# Epoch 36/50
# 200/200 [==============================] - 7s 37ms/step - loss: 1.5662 - accuracy: 0.6616 - val_loss: 23.0048 - val_accuracy: 0.0094
# Epoch 37/50
# 200/200 [==============================] - 6s 30ms/step - loss: 1.5587 - accuracy: 0.6612 - val_loss: 22.8795 - val_accuracy: 0.0094
# Epoch 38/50
# 200/200 [==============================] - 5s 26ms/step - loss: 1.5544 - accuracy: 0.6617 - val_loss: 22.8322 - val_accuracy: 0.0119
# Epoch 39/50
# 200/200 [==============================] - 7s 37ms/step - loss: 1.5499 - accuracy: 0.6597 - val_loss: 23.1556 - val_accuracy: 0.0125
# Epoch 40/50
# 200/200 [==============================] - 6s 30ms/step - loss: 1.5437 - accuracy: 0.6598 - val_loss: 22.8977 - val_accuracy: 0.0100
# Epoch 41/50
# 200/200 [==============================] - 5s 25ms/step - loss: 1.5412 - accuracy: 0.6606 - val_loss: 22.8933 - val_accuracy: 0.0106
# Epoch 42/50
# 200/200 [==============================] - 8s 41ms/step - loss: 1.5349 - accuracy: 0.6628 - val_loss: 22.7399 - val_accuracy: 0.0100
# Epoch 43/50
# 200/200 [==============================] - 7s 33ms/step - loss: 1.5346 - accuracy: 0.6600 - val_loss: 22.7640 - val_accuracy: 0.0113
# Epoch 44/50
# 200/200 [==============================] - 5s 25ms/step - loss: 1.5316 - accuracy: 0.6606 - val_loss: 22.8690 - val_accuracy: 0.0106
# Epoch 45/50
# 200/200 [==============================] - 6s 30ms/step - loss: 1.5240 - accuracy: 0.6616 - val_loss: 23.2467 - val_accuracy: 0.0113
# Epoch 46/50
# 200/200 [==============================] - 7s 36ms/step - loss: 1.5214 - accuracy: 0.6597 - val_loss: 23.0862 - val_accuracy: 0.0100
# Epoch 47/50
# 200/200 [==============================] - 6s 31ms/step - loss: 1.5216 - accuracy: 0.6589 - val_loss: 23.3488 - val_accuracy: 0.0106
# Epoch 48/50
# 200/200 [==============================] - 5s 27ms/step - loss: 1.5191 - accuracy: 0.6592 - val_loss: 23.3418 - val_accuracy: 0.0100
# Epoch 49/50
# 200/200 [==============================] - 8s 41ms/step - loss: 1.5134 - accuracy: 0.6617 - val_loss: 23.3825 - val_accuracy: 0.0100
# Epoch 50/50
# 200/200 [==============================] - 6s 29ms/step - loss: 1.5136 - accuracy: 0.6591 - val_loss: 23.1675 - val_accuracy: 0.0106

# %% [markdown]
# I've altered the test size by 10 percent for each graph to test the model. I just wanted to see how the model adjusted to evaluate it's performance on unseen data.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt

# Assuming 'Word' is the target variable and 'Clue' is the feature
X = train_df['Clue']
y = train_df['Word']

# Drop rows with missing values
nyt = train_df.dropna(subset=['Clue', 'Word'])

# Convert text data to numerical features using Tokenizer
max_words = 1000
tokenizer = Tokenizer(num_words=max_words, oov_token='<OOV>')
tokenizer.fit_on_texts(X)
X_sequence = tokenizer.texts_to_sequences(X)
X_padded = pad_sequences(X_sequence)

# Convert target variable to categorical
y_categorical = pd.get_dummies(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_padded, y_categorical, test_size=0.3, random_state=42)

# Build the neural network model
model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=50, input_length=X_padded.shape[1]))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(y_categorical.shape[1], activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model and capture the training history
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 175/175 [==============================] - 5s 27ms/step - loss: 8.8960 - accuracy: 3.5714e-04 - val_loss: 8.9176 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 175/175 [==============================] - 6s 36ms/step - loss: 8.7891 - accuracy: 8.9286e-04 - val_loss: 9.0755 - val_accuracy: 7.1429e-04
# Epoch 3/50
# 175/175 [==============================] - 6s 37ms/step - loss: 8.3502 - accuracy: 0.0027 - val_loss: 9.7951 - val_accuracy: 7.1429e-04
# Epoch 4/50
# 175/175 [==============================] - 5s 31ms/step - loss: 7.2114 - accuracy: 0.0136 - val_loss: 11.5481 - val_accuracy: 7.1429e-04
# Epoch 5/50
# 175/175 [==============================] - 5s 30ms/step - loss: 6.0919 - accuracy: 0.0593 - val_loss: 13.3053 - val_accuracy: 7.1429e-04
# Epoch 6/50
# 175/175 [==============================] - 7s 38ms/step - loss: 5.2205 - accuracy: 0.1229 - val_loss: 14.7407 - val_accuracy: 0.0014
# Epoch 7/50
# 175/175 [==============================] - 7s 40ms/step - loss: 4.5518 - accuracy: 0.1852 - val_loss: 16.2206 - val_accuracy: 7.1429e-04
# Epoch 8/50
# 175/175 [==============================] - 4s 26ms/step - loss: 4.0189 - accuracy: 0.2609 - val_loss: 17.2758 - val_accuracy: 0.0029
# Epoch 9/50
# 175/175 [==============================] - 7s 38ms/step - loss: 3.5857 - accuracy: 0.3259 - val_loss: 18.3796 - val_accuracy: 0.0036
# Epoch 10/50
# 175/175 [==============================] - 6s 33ms/step - loss: 3.2262 - accuracy: 0.3930 - val_loss: 19.3006 - val_accuracy: 0.0043
# Epoch 11/50
# 175/175 [==============================] - 5s 27ms/step - loss: 2.9130 - accuracy: 0.4454 - val_loss: 20.0981 - val_accuracy: 0.0043
# Epoch 31/50
# 175/175 [==============================] - 7s 38ms/step - loss: 1.5450 - accuracy: 0.6693 - val_loss: 22.8467 - val_accuracy: 0.0093
# Epoch 32/50
# 175/175 [==============================] - 5s 31ms/step - loss: 1.5342 - accuracy: 0.6675 - val_loss: 22.7482 - val_accuracy: 0.0086
# Epoch 33/50
# 175/175 [==============================] - 4s 26ms/step - loss: 1.5239 - accuracy: 0.6687 - val_loss: 22.6178 - val_accuracy: 0.0093
# Epoch 34/50
# 175/175 [==============================] - 7s 38ms/step - loss: 1.5160 - accuracy: 0.6693 - val_loss: 22.9644 - val_accuracy: 0.0093
# Epoch 35/50
# 175/175 [==============================] - 7s 39ms/step - loss: 1.5112 - accuracy: 0.6739 - val_loss: 22.6098 - val_accuracy: 0.0107
# Epoch 36/50
# 175/175 [==============================] - 5s 26ms/step - loss: 1.5033 - accuracy: 0.6704 - val_loss: 22.8000 - val_accuracy: 0.0100
# Epoch 37/50
# 175/175 [==============================] - 5s 26ms/step - loss: 1.4989 - accuracy: 0.6739 - val_loss: 22.6746 - val_accuracy: 0.0093
# Epoch 38/50
# 175/175 [==============================] - 7s 37ms/step - loss: 1.4907 - accuracy: 0.6707 - val_loss: 22.4428 - val_accuracy: 0.0093
# Epoch 39/50
# 175/175 [==============================] - 6s 36ms/step - loss: 1.4893 - accuracy: 0.6739 - val_loss: 22.1260 - val_accuracy: 0.0086
# Epoch 40/50
# 175/175 [==============================] - 5s 27ms/step - loss: 1.4861 - accuracy: 0.6679 - val_loss: 23.0432 - val_accuracy: 0.0093
# Epoch 41/50
# 175/175 [==============================] - 5s 30ms/step - loss: 1.4803 - accuracy: 0.6725 - val_loss: 22.3862 - val_accuracy: 0.0086
# Epoch 42/50
# 175/175 [==============================] - 7s 38ms/step - loss: 1.4754 - accuracy: 0.6696 - val_loss: 22.5523 - val_accuracy: 0.0114
# Epoch 43/50
# 175/175 [==============================] - 5s 29ms/step - loss: 1.4736 - accuracy: 0.6682 - val_loss: 22.5285 - val_accuracy: 0.0086
# Epoch 44/50
# 175/175 [==============================] - 4s 25ms/step - loss: 1.4705 - accuracy: 0.6682 - val_loss: 22.8198 - val_accuracy: 0.0079
# Epoch 45/50
# 175/175 [==============================] - 6s 37ms/step - loss: 1.4641 - accuracy: 0.6711 - val_loss: 22.5534 - val_accuracy: 0.0079
# Epoch 46/50
# 175/175 [==============================] - 7s 40ms/step - loss: 1.4620 - accuracy: 0.6704 - val_loss: 22.2927 - val_accuracy: 0.0079
# Epoch 47/50
# 175/175 [==============================] - 5s 26ms/step - loss: 1.4583 - accuracy: 0.6709 - val_loss: 22.1353 - val_accuracy: 0.0093
# Epoch 48/50
# 175/175 [==============================] - 5s 26ms/step - loss: 1.4559 - accuracy: 0.6707 - val_loss: 22.7250 - val_accuracy: 0.0100
# Epoch 49/50
# 175/175 [==============================] - 6s 36ms/step - loss: 1.4555 - accuracy: 0.6714 - val_loss: 22.6254 - val_accuracy: 0.0093
# Epoch 50/50
# 175/175 [==============================] - 6s 35ms/step - loss: 1.4495 - accuracy: 0.6716 - val_loss: 22.5338 - val_accuracy: 0.0114

# %% [markdown]
# This last analysis used 40 percent of the dataset as a test set and 60 percent as a training set. Considering the idea that this model doesn't really account for the a few of the variables that I will need to include in later parts of this project (ie. token size, adjacenct token matching) I wanted to understand if the model could learn without the entirety of the dataset that I originally wanted to use.
#
# It's (almost) clear that the validation loss suffers less with a larger test size, but in future parts of this project, I will explore the limits of what I can use in the dataset and also how to effectively adjust the amount of epochs I should use to have a better accuracy.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt

# Assuming 'Word' is the target variable and 'Clue' is the feature
X = train_df['Clue']
y = train_df['Word']

# Drop rows with missing values
nyt = train_df.dropna(subset=['Clue', 'Word'])

# Convert text data to numerical features using Tokenizer
max_words = 1000
tokenizer = Tokenizer(num_words=max_words, oov_token='<OOV>')
tokenizer.fit_on_texts(X)
X_sequence = tokenizer.texts_to_sequences(X)
X_padded = pad_sequences(X_sequence)

# Convert target variable to categorical
y_categorical = pd.get_dummies(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_padded, y_categorical, test_size=0.4, random_state=42)

# Build the neural network model
model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=50, input_length=X_padded.shape[1]))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(y_categorical.shape[1], activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model and capture the training history
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 150/150 [==============================] - 6s 35ms/step - loss: 8.8948 - accuracy: 4.1667e-04 - val_loss: 8.9086 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 150/150 [==============================] - 7s 44ms/step - loss: 8.7645 - accuracy: 6.2500e-04 - val_loss: 9.1587 - val_accuracy: 0.0017
# Epoch 3/50
# 150/150 [==============================] - 4s 28ms/step - loss: 8.5012 - accuracy: 0.0025 - val_loss: 9.5458 - val_accuracy: 0.0017
# Epoch 4/50
# 150/150 [==============================] - 4s 25ms/step - loss: 7.9282 - accuracy: 0.0037 - val_loss: 10.4908 - val_accuracy: 8.3333e-04
# Epoch 5/50
# 150/150 [==============================] - 5s 34ms/step - loss: 6.8907 - accuracy: 0.0158 - val_loss: 11.9452 - val_accuracy: 8.3333e-04
# Epoch 6/50
# 150/150 [==============================] - 6s 37ms/step - loss: 5.9330 - accuracy: 0.0592 - val_loss: 13.7626 - val_accuracy: 8.3333e-04
# Epoch 7/50
# 150/150 [==============================] - 4s 28ms/step - loss: 5.1488 - accuracy: 0.1242 - val_loss: 14.9015 - val_accuracy: 0.0033
# Epoch 8/50
# 150/150 [==============================] - 4s 25ms/step - loss: 4.4883 - accuracy: 0.1985 - val_loss: 16.4983 - val_accuracy: 0.0017
# Epoch 9/50
# 150/150 [==============================] - 5s 34ms/step - loss: 3.9446 - accuracy: 0.2715 - val_loss: 17.2932 - val_accuracy: 0.0042
# Epoch 10/50
# 150/150 [==============================] - 6s 40ms/step - loss: 3.5187 - accuracy: 0.3340 - val_loss: 18.4203 - val_accuracy: 0.0050
# Epoch 11/50
# 150/150 [==============================] - 5s 31ms/step - loss: 3.1710 - accuracy: 0.3996 - val_loss: 19.0668 - val_accuracy: 0.0050
# Epoch 12/50
# 150/150 [==============================] - 4s 26ms/step - loss: 2.8926 - accuracy: 0.4473 - val_loss: 19.9475 - val_accuracy: 0.0067
